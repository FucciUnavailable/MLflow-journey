# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("my-first-experiment")
# Out:
# 2026/06/30 21:13:04 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/06/30 21:13:04 INFO mlflow.store.db.utils: Updating database tables
# 2026/06/30 21:13:07 INFO mlflow.tracking.fluent: Experiment with name 'my-first-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/home/fucci/repos/jupyter-mlflow-iris/mlruns/1', creation_time=1782879187335, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1782879187335, lifecycle_stage='active', name='my-first-experiment', tags={}, trace_location=None, workspace='default'>

# %%
import mlflow

# Print connection information
print(f"MLflow Tracking URI: {mlflow.get_tracking_uri()}")
print(f"Active Experiment: {mlflow.get_experiment_by_name('my-first-experiment')}")

# Test logging
with mlflow.start_run():
    mlflow.log_param("test_param", "test_value")
    print("✓ Successfully connected to MLflow!")
# Out:
# MLflow Tracking URI: sqlite:///mlflow.db
# Active Experiment: <Experiment: artifact_location='/home/fucci/repos/jupyter-mlflow-iris/mlruns/1', creation_time=1782879187335, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1782879187335, lifecycle_stage='active', name='my-first-experiment', tags={}, trace_location=None, workspace='default'>
# ✓ Successfully connected to MLflow!
